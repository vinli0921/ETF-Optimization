# %% [markdown]
# # ETF Portfolio Optimization - Baseline Demo
#
# This notebook demonstrates the baseline portfolio optimization system with:
# - Data loading and preprocessing
# - Feature engineering
# - Baseline strategies (Equal Weight, Mean-Variance)
# - Backtesting and performance evaluation
# - Comprehensive visualizations

# %%
# Add src to path
import sys
sys.path.append('../src')

# Core imports
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# Project imports
from data import ETFDataLoader, load_default_etfs
from features import FeatureEngineer, create_feature_summary
from strategies import (
    EqualWeightStrategy, MeanVarianceStrategy, 
    PredictiveSharpeStrategy, create_60_40_strategy, RiskAdjustedLSTMStrategy,
    GradientBoostingSharpeStrategy, XGBoostSharpeStrategy  # NEW: ML strategies
)
from backtest import PortfolioBacktest, compare_strategies
from metrics import calculate_all_metrics, compare_strategies as compare_metrics, format_metrics_table
from visualization import (
    plot_equity_curves, plot_drawdown, plot_multiple_drawdowns,
    plot_allocation_over_time, plot_correlation_matrix,
    plot_rolling_sharpe, create_performance_dashboard
)
import importlib
import sentiment
importlib.reload(sentiment)
from sentiment import compute_all_etf_sentiment




# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.precision', 4)

# %% [markdown]
# ## 1. Load Data
#
# Load historical price data for VTI, BND, and QQQ ETFs.

# %%
# Load expanded ETF set (10 ETFs: core 6 + VEA, VWO, IWM, XLE)
prices = load_default_etfs(start_date='2015-01-01', expanded=True)

print(f"\nLoaded {len(prices)} days of data")
print(f"ETFs: {', '.join(prices.columns)}")
print(f"Date range: {prices.index[0].date()} to {prices.index[-1].date()}")

# %%
# Show summary statistics
loader = ETFDataLoader()
summary = loader.get_data_summary(prices)
print("\n" + "="*80)
print("ETF Summary Statistics")
print("="*80)
print(summary)
# Out:
# ================================================================================
# ETF Summary Statistics
# ================================================================================
#                                            BND                  GLD  \
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2025-12-05 00:00:00  2025-12-05 00:00:00
# Days                                      2749                 2749
# Mean Daily Return (%)                    0.008               0.0487
# Daily Volatility (%)                    0.3387               0.9259
# Annualized Return (%)                   2.0035              12.2714
# Annualized Volatility (%)               5.3764              14.6977
# Total Return (%)                       22.4674             238.7447
# Min Price                              59.8979                100.5
# Max Price                              76.3221               403.15
#
#                                            QQQ                  SPY  \
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2025-12-05 00:00:00  2025-12-05 00:00:00
# Days                                      2749                 2749
# Mean Daily Return (%)                   0.0783               0.0569
# Daily Volatility (%)                    1.3872               1.1233
# Annualized Return (%)                  19.7264              14.3274
# Annualized Volatility (%)              22.0218              17.8322
# Total Return (%)                      559.0484             300.7688
# Min Price                              89.7023             155.4389
# Max Price                               635.77               687.39
#
#                                            TLT                  VTI
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2025-12-05 00:00:00  2025-12-05 00:00:00
# Days                                      2749                 2749
# Mean Daily Return (%)                   0.0017               0.0554
# Daily Volatility (%)                    0.9497               1.1439
# Annualized Return (%)                   0.4391              13.9495
# Annualized Volatility (%)              15.0762              18.1592
# Total Return (%)                       -7.3156             282.1041
# Min Price                              75.6673              78.7364
# Max Price                             146.5034               337.95

# %%
# Visualize price history
fig, ax = plt.subplots(figsize=(14, 6))
normalized_prices = prices / prices.iloc[0] * 100
normalized_prices.plot(ax=ax, linewidth=2)
ax.set_title('ETF Price History (Normalized to 100)', fontsize=14, fontweight='bold')
ax.set_xlabel('Date', fontsize=12)
ax.set_ylabel('Normalized Price', fontsize=12)
ax.legend(fontsize=11)
ax.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 2. Split Data
#
# Split data into train, validation, and test sets:
# - **Train**: 2015-2021 (used for strategy development)
# - **Validation**: 2022 (used for hyperparameter tuning)
# - **Test**: 2023-2025 (held-out for final evaluation)

# %%
# Split data
train, val, test = loader.split_train_val_test(prices)

print("\n" + "="*80)
print("Training Set Summary")
print("="*80)
print(loader.get_data_summary(train))
# Out:
# Data split:
#   Train: 2015-01-02 to 2021-12-31 (1763 days)
#   Val:   2022-01-03 to 2022-12-30 (251 days)
#   Test:  2023-01-04 to 2025-12-05 (734 days)
#
# ================================================================================
# Training Set Summary
# ================================================================================
#                                            BND                  GLD  \
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2021-12-31 00:00:00  2021-12-31 00:00:00
# Days                                      1763                 1763
# Mean Daily Return (%)                   0.0122               0.0268
# Daily Volatility (%)                    0.2915                0.877
# Annualized Return (%)                   3.0774               6.7554
# Annualized Volatility (%)               4.6267              13.9215
# Total Return (%)                       23.0774              49.8598
# Min Price                              59.8979                100.5
# Max Price                              76.3221               193.89
#
#                                            QQQ                  SPY  \
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2021-12-31 00:00:00  2021-12-31 00:00:00
# Days                                      1763                 1763
# Mean Daily Return (%)                   0.0888               0.0612
# Daily Volatility (%)                    1.3206               1.1134
# Annualized Return (%)                  22.3701              15.4237
# Annualized Volatility (%)              20.9644              17.6744
# Total Return (%)                      309.2918             163.3653
# Min Price                              89.7023             155.4389
# Max Price                             393.9416             452.9922
#
#                                            TLT                  VTI
# Start Date                 2015-01-02 00:00:00  2015-01-02 00:00:00
# End Date                   2021-12-31 00:00:00  2021-12-31 00:00:00
# Days                                      1763                 1763
# Mean Daily Return (%)                   0.0213               0.0604
# Daily Volatility (%)                    0.8875               1.1333
# Annualized Return (%)                   5.3667                15.23
# Annualized Volatility (%)              14.0881              17.9902
# Total Return (%)                       35.7877             158.7896
# Min Price                              86.9841              78.7364
# Max Price                             146.5034             230.0603

# %% [markdown]
# ## 3. Feature Engineering
#
# Compute features for portfolio optimization:
# - Daily returns
# - Rolling volatility (30-day)
# - Rolling momentum (30-day)
# - Rolling Sharpe ratio
# - Average correlation with other assets

# %%
# Create feature engineer
feature_eng = FeatureEngineer(lookback_window=30)

# Compute features on training data
features_train = feature_eng.compute_all_features(train)

print(f"\nComputed {len(features_train.columns)} features")
print(f"Feature columns: {', '.join(features_train.columns[:10])}...")
# Out:
# Computed 30 features
# Feature columns: BND, GLD, QQQ, SPY, TLT, VTI, BND_volatility, GLD_volatility, QQQ_volatility, SPY_volatility...

# %%
# Show feature summary
print("\n" + "="*80)
print("Feature Summary (Training Data)")
print("="*80)
print(create_feature_summary(features_train))
# Out:
# ================================================================================
# Feature Summary (Training Data)
# ================================================================================
#                 Count    Mean     Std     Min      Max  NaN Count
# BND              1762  0.0001  0.0029 -0.0544   0.0422          1
# GLD              1762  0.0003  0.0088 -0.0537   0.0490          1
# QQQ              1762  0.0009  0.0132 -0.1198   0.0847          1
# SPY              1762  0.0006  0.0111 -0.1094   0.0906          1
# TLT              1762  0.0002  0.0089 -0.0667   0.0752          1
# VTI              1762  0.0006  0.0113 -0.1138   0.0949          1
# BND_volatility   1733  0.0358  0.0301  0.0136   0.2605         30
# GLD_volatility   1733  0.1315  0.0458  0.0656   0.3577         30
# QQQ_volatility   1733  0.1817  0.1073  0.0539   0.8154         30
# SPY_volatility   1733  0.1436  0.1048  0.0352   0.8214         30
# TLT_volatility   1733  0.1283  0.0584  0.0673   0.5171         30
# VTI_volatility   1733  0.1459  0.1068  0.0369   0.8420         30
# BND_momentum     1733  0.0300  0.1025 -0.4515   0.7612         30
# GLD_momentum     1733  0.0583  0.3825 -1.1760   1.3192         30
# QQQ_momentum     1733  0.2263  0.4784 -2.2531   2.1653         30
# SPY_momentum     1733  0.1547  0.4281 -3.0512   2.2141         30
# TLT_momentum     1733  0.0493  0.3603 -0.9862   1.6242         30
# VTI_momentum     1733  0.1532  0.4494 -3.1875   2.2663         30
# BND_sharpe       1733  0.4209  3.0160 -7.7700  10.6131         30
# GLD_sharpe       1733  0.2303  3.0453 -9.5922  11.4812         30
# QQQ_sharpe       1733  1.8153  2.7084 -5.3383  11.1759         30
# SPY_sharpe       1733  1.7051  2.6602 -6.7805   9.8113         30
# TLT_sharpe       1733  0.2103  2.6793 -7.6682   8.7834         30
# VTI_sharpe       1733  1.6441  2.6784 -6.8770   9.6176         30
# BND_avg_corr     1733  0.1732  0.1699 -0.1999   0.7202         30
# GLD_avg_corr     1733  0.1209  0.1456 -0.1689   0.5392         30
# QQQ_avg_corr     1733  0.2873  0.1578 -0.0637   0.7159         30
# SPY_avg_corr     1733  0.2674  0.1553 -0.0723   0.7408         30
# TLT_avg_corr     1733  0.0801  0.1798 -0.4181   0.6347         30
# VTI_avg_corr     1733  0.2646  0.1558 -0.0746   0.7300         30

# %%
# Visualize correlations
returns_train = loader.calculate_returns(train).dropna()
plot_correlation_matrix(returns_train, title='Training Set: Asset Correlation Matrix')
plt.show()

# %% [markdown]
# ## 4. Define Strategies
#
# We'll compare seven strategies across 10 ETFs:
#
# ### Traditional Strategies:
# 1. **Equal Weight**: Simple 1/N allocation across all ETFs
# 2. **Mean-Variance (Max Sharpe)**: Optimize for maximum Sharpe ratio using historical returns
# 3. **60/40 Portfolio**: Traditional 60% stocks / 40% bonds allocation
#
# ### Machine Learning Strategies:
# 4. **Predictive Sharpe**: Ridge regression to predict returns, then optimize for max Sharpe
#    - Regularized return predictions (Ridge regression)
#    - Ledoit-Wolf shrinkage covariance
#    - James-Stein style shrinkage on predicted returns
#
# 5. **LightGBM ML**: Gradient boosting with Sharpe-optimized portfolio
#    - Predicts returns using LightGBM with extensive features
#    - Conservative hyperparameters (depth=3, high regularization)
#    - Ledoit-Wolf covariance shrinkage
#
# 6. **XGBoost ML**: Alternative gradient boosting implementation
#    - More conservative than LightGBM (level-wise tree growth)
#    - Better for small datasets with many features
#    - Same feature set as LightGBM
#
# 7. **Risk-Adjusted LSTM**: Deep learning with LSTM network
#    - Hyperparameters tuned on validation set
#    - Trained on train+validation data

# %%
import importlib
import strategies
import lstm_model

importlib.reload(strategies)
importlib.reload(lstm_model)
# Out:
# <module 'lstm_model' from '/Users/joshlee/Desktop/ETF-Optimization/notebooks/../src/lstm_model.py'>

# %%
import backtest
from backtest import PortfolioBacktest
importlib.reload(backtest)
def compute_sharpe(portfolio_values):
    returns = portfolio_values.pct_change().dropna()
    if returns.std() == 0:
        return -1e9
    return returns.mean() / returns.std()
best_score = -1e9
best_params = None
best_strategy = None
results = []   # <--- store all experiment outcomes
for lb in [20,30,40]:
    for hd in [16, 32,64]:
        for ep in [30]:

            print(f"Testing: lookback={lb}, hidden={hd}, epochs={ep}")

            # build strategy
            strat = RiskAdjustedLSTMStrategy(
                lookback=lb,
                hidden_dim=hd,
                epochs=ep,
                lr=1e-3
            )
            strat.train_on_data(train)
            
            bt = PortfolioBacktest(
                initial_capital=100000,
                transaction_cost=0.001,
                rebalance_frequency='M'
            )

            validation_values = bt.run(strat, val)

            # compute Sharpe
            validation_sharpe = compute_sharpe(validation_values)

            print("Validation Sharpe:", validation_sharpe)
            results.append({
                "lookback": lb,
                "hidden_dim": hd,
                "epochs": ep,
                "sharpe": validation_sharpe
            })
            # update best
            if validation_sharpe > best_score:
                best_score = validation_sharpe
                best_params = (lb, hd, ep)
                best_strategy = strat

print("\nBEST MODEL:")
print(best_params, "Sharpe =", best_score)
# Out:
# Testing: lookback=20, hidden=16, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.0680826330184305
# Testing: lookback=20, hidden=32, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.06362811529666704
# Testing: lookback=20, hidden=64, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.06106785970548293
# Testing: lookback=30, hidden=16, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.06405073245034072
# Testing: lookback=30, hidden=32, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.0680917626626474
# Testing: lookback=30, hidden=64, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.07481612609129884
# Testing: lookback=40, hidden=16, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.061581211753473884
# Testing: lookback=40, hidden=32, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.06403416405529588
# Testing: lookback=40, hidden=64, epochs=30
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Validation Sharpe: -0.0655480505409978
#
# BEST MODEL:
# (20, 64, 30) Sharpe = -0.06106785970548293

# %%
df = pd.DataFrame(results)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

pivot = df.pivot_table(
    index="lookback",
    columns="hidden_dim",
    values="sharpe",
    aggfunc="max"    # or "mean"
)

plt.figure(figsize=(8, 5))
sns.heatmap(pivot, annot=True, cmap="coolwarm", fmt=".3f")
plt.title("Sharpe Ratio by Lookback and Hidden Dim")
plt.ylabel("Lookback")
plt.xlabel("Hidden Dim")
plt.show()

# %%
#Retrain Final Model on TRAIN + VAL
lb,hd,ep=best_params

#Combine train + val into one dataset for final training
trainval=prices.loc[train.index[0] : val.index[-1]]

final_lstm=RiskAdjustedLSTMStrategy(lookback=lb,hidden_dim=hd,epochs=ep,lr=1e-3)
final_lstm.train_on_data(pd.concat([train, val]))
print(">>> Final LSTM Model Retrained on Train+Val")
# Out:
# >>> Final LSTM Model Retrained on Train+Val

# %%
# Define strategies
from strategies import (
    EqualWeightStrategy, MeanVarianceStrategy, 
    PredictiveSharpeStrategy, create_60_40_strategy, RiskAdjustedLSTMStrategy,
    GradientBoostingSharpeStrategy, XGBoostSharpeStrategy  # NEW: ML strategies
)
strategies = {
    'Equal Weight': EqualWeightStrategy(),
    'Mean-Variance (Max Sharpe)': MeanVarianceStrategy(lookback_days=252, method='max_sharpe'),
    'Predictive Sharpe': PredictiveSharpeStrategy(),
    '60/40 Portfolio': create_60_40_strategy(
        stock_tickers=['VTI', 'QQQ', 'SPY', 'VEA', 'VWO', 'IWM', 'XLE'],  # 7 stock ETFs
        bond_tickers=['BND', 'TLT', 'GLD']  # 3 bond/alt ETFs
    ),
    'LightGBM ML': GradientBoostingSharpeStrategy(
        lookback_days=756,
        feature_window=60,
        min_history_days=60,
        n_estimators=100,
        max_depth=3,
        learning_rate=0.01,
        subsample=0.8,
        colsample_bytree=0.6,
        reg_alpha=1.0,
        reg_lambda=10.0,
        shrinkage_intensity=0.25,
        max_weight=0.4,
        risk_free_rate=0.02
    ),
    'XGBoost ML': XGBoostSharpeStrategy(
        lookback_days=756,
        feature_window=60,
        min_history_days=60,
        n_estimators=100,
        max_depth=3,
        learning_rate=0.01,
        subsample=0.8,
        colsample_bytree=0.6,
        reg_alpha=1.0,
        reg_lambda=10.0,
        shrinkage_intensity=0.25,
        max_weight=0.4,
        risk_free_rate=0.02
    ),
    "Risk-Adjusted LSTM": final_lstm
}

# %%
# Show initial allocations
print("\n" + "="*80)
print("Initial Allocations (using full training data)")
print("="*80)
for name, strategy in strategies.items():
    weights = strategy.allocate(trainval)
    print(f"\n{name}:")
    for ticker, weight in weights.items():
        print(f"  {ticker}: {weight:>6.2%}")
# Out:
# ================================================================================
# Initial Allocations (using full training data)
# ================================================================================
#
# Equal Weight:
#   BND: 16.67%
#   GLD: 16.67%
#   QQQ: 16.67%
#   SPY: 16.67%
#   TLT: 16.67%
#   VTI: 16.67%
#
# Mean-Variance (Max Sharpe):
#   BND: 61.78%
#   GLD: 25.41%
#   QQQ:  0.00%
#   SPY:  7.42%
#   TLT:  1.75%
#   VTI:  3.63%
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
#
# Predictive Sharpe:
#   BND: 16.67%
#   GLD: 16.67%
#   QQQ: 16.67%
#   SPY: 16.67%
#   TLT: 16.67%
#   VTI: 16.67%
#
# 60/40 Portfolio:
#   BND: 20.00%
#   GLD:  0.00%
#   QQQ: 20.00%
#   SPY: 20.00%
#   TLT: 20.00%
#   VTI: 20.00%
#
# Risk-Adjusted LSTM:
#   BND: 12.20%
#   GLD: 17.84%
#   QQQ: 18.64%
#   SPY: 19.26%
#   TLT:  9.94%
#   VTI: 22.13%

# %% [markdown]
# ## 5. Backtest on Training Data
#
# Run backtest with monthly rebalancing and 0.1% transaction costs.

# %%
# Run backtest on training data
print("\n" + "="*80)
print("Backtesting on Training Data (2015-2021)")
print("="*80)

results_train, allocations_train = compare_strategies(
    strategies,
    train,
    initial_capital=100000,
    transaction_cost=0.001,  # 0.1%
    rebalance_frequency='M'   # Monthly
)
# Out:
# ================================================================================
# Backtesting on Training Data (2015-2021)
# ================================================================================
# Running backtest for Equal Weight
#   Period: 2015-01-02 to 2021-12-31
#   Rebalancing: M (58 times)
#   Final value: $208,471.17
#
# Running backtest for Mean-Variance Optimization
#   Period: 2015-01-02 to 2021-12-31
#   Rebalancing: M (58 times)
#   Final value: $149,054.84
#
# Running backtest for Predictive Sharpe (Ridge Regression)
#   Period: 2015-01-02 to 2021-12-31
#   Rebalancing: M (58 times)
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
#   Final value: $150,062.77
#
# Running backtest for Static Allocation
#   Period: 2015-01-02 to 2021-12-31
#   Rebalancing: M (58 times)
#   Final value: $219,716.15
#
# Running backtest for Risk Adjusted LSTM
#   Period: 2015-01-02 to 2021-12-31
#   Rebalancing: M (58 times)
#   Final value: $218,249.51

# %%
# Calculate metrics
metrics_train = compare_metrics(results_train, allocations_train)
metrics_train_formatted = format_metrics_table(metrics_train)

print("\n" + "="*80)
print("Training Set Performance Metrics")
print("="*80)
print(metrics_train_formatted.to_string())
# Out:
# ================================================================================
# Training Set Performance Metrics
# ================================================================================
#                             Total Return  Annualized Return  Annualized Volatility  Sharpe Ratio  Sortino Ratio  Max Drawdown  Calmar Ratio  Win Rate  Downside Periods  Avg Turnover
# Equal Weight                    108.4712            11.0732                 9.0832        0.9989         1.1645       16.7234        0.6621   55.0511             732.0        0.0000
# Mean-Variance (Max Sharpe)       49.0548             5.8719                12.0565        0.3211         0.3688       21.4946        0.2732   55.3916             726.0       21.3834
# Predictive Sharpe                50.0628             5.9739                 9.7679        0.4068         0.4793       16.7507        0.3566   53.9160             752.0       44.8283
# 60/40 Portfolio                 119.7162            11.9105                10.2741        0.9646         1.0954       18.5692        0.6414   55.6186             722.0        0.0000
# Risk-Adjusted LSTM              118.2495            11.8034                 9.5993        1.0213         1.1664       17.4145        0.6778   55.1078             731.0       23.7305

# %%
# Visualize equity curves
plot_equity_curves(results_train, title='Training Set: Portfolio Performance')
plt.show()

# %%
# Visualize drawdowns
plot_multiple_drawdowns(results_train, title='Training Set: Drawdown Comparison')
plt.show()

# %%
# Visualize allocation dynamics for Mean-Variance strategy
if 'Mean-Variance (Max Sharpe)' in allocations_train:
    plot_allocation_over_time(
        allocations_train['Mean-Variance (Max Sharpe)'],
        title='Mean-Variance Strategy: Allocation Over Time (Training)'
    )
    plt.show()

# %% [markdown]
# ## 6. Backtest on Validation Data
#
# Evaluate strategies on validation set (2022).

# %%
# Run backtest on validation data
print("\n" + "="*80)
print("Backtesting on Validation Data (2022)")
print("="*80)

results_val, allocations_val = compare_strategies(
    strategies,
    val,
    initial_capital=100000,
    transaction_cost=0.001,
    rebalance_frequency='M'
)
# Out:
# ================================================================================
# Backtesting on Validation Data (2022)
# ================================================================================
# Running backtest for Equal Weight
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
#   Final value: $84,511.11
#
# Running backtest for Mean-Variance Optimization
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Warning: Insufficient data (19 days), using equal weights
#   Final value: $88,826.68
#
# Running backtest for Predictive Sharpe (Ridge Regression)
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
# Warning: Insufficient data (19 days), using equal weights
# Warning: Insufficient data (38 days), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
# Warning: Predictive optimization failed (at least one of the assets must have an expected return exceeding the risk-free rate), using equal weights
#   Final value: $83,722.91
#
# Running backtest for Static Allocation
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
#   Final value: $81,356.83
#
# Running backtest for Risk Adjusted LSTM
#   Period: 2022-01-03 to 2022-12-30
#   Rebalancing: M (9 times)
#   Final value: $84,118.64

# %%
# Calculate metrics
metrics_val = compare_metrics(results_val, allocations_val)
metrics_val_formatted = format_metrics_table(metrics_val)

print("\n" + "="*80)
print("Validation Set Performance Metrics")
print("="*80)
print(metrics_val_formatted.to_string())
# Out:
# ================================================================================
# Validation Set Performance Metrics
# ================================================================================
#                             Total Return  Annualized Return  Annualized Volatility  Sharpe Ratio  Sortino Ratio  Max Drawdown  Calmar Ratio  Win Rate  Downside Periods  Avg Turnover
# Equal Weight                    -15.4889           -15.6562                15.4021       -1.1463        -1.8250       20.6666       -0.7576      42.0             126.0        0.0000
# Mean-Variance (Max Sharpe)      -11.1733           -11.2971                11.2457       -1.1824        -1.8229       19.6179       -0.5759      42.4             125.0       18.8216
# Predictive Sharpe               -16.2771           -16.4520                16.3175       -1.1308        -1.7021       21.4065       -0.7686      42.0             126.0       22.5926
# 60/40 Portfolio                 -18.6432           -18.8405                17.4662       -1.1932        -1.9531       22.8858       -0.8232      41.6             127.0        0.0000
# Risk-Adjusted LSTM              -15.8814           -16.0525                15.3381       -1.1770        -1.8711       21.1722       -0.7582      42.8             124.0        8.4456

# %%
# Visualize validation results
plot_equity_curves(results_val, title='Validation Set: Portfolio Performance')
plt.show()

# %% [markdown]
# ## 7. Backtest on Test Data
#
# Final evaluation on held-out test set (2023-2025).

# %%
# Run backtest on test data
print("\n" + "="*80)
print("Backtesting on Test Data (2023-2025)")
print("="*80)

results_test, allocations_test = compare_strategies(
    strategies,
    test,
    initial_capital=100000,
    transaction_cost=0.001,
    rebalance_frequency='M'
)
# Out:
# ================================================================================
# Backtesting on Test Data (2023-2025)
# ================================================================================
# Running backtest for Equal Weight
#   Period: 2023-01-04 to 2025-12-05
#   Rebalancing: M (25 times)
#   Final value: $157,813.26
#
# Running backtest for Mean-Variance Optimization
#   Period: 2023-01-04 to 2025-12-05
#   Rebalancing: M (25 times)
# Warning: Insufficient data (18 days), using equal weights
#   Final value: $209,855.16
#
# Running backtest for Predictive Sharpe (Ridge Regression)
#   Period: 2023-01-04 to 2025-12-05
#   Rebalancing: M (25 times)
# Warning: Insufficient data (18 days), using equal weights
# Warning: Insufficient data (37 days), using equal weights
#   Final value: $159,158.30
#
# Running backtest for Static Allocation
#   Period: 2023-01-04 to 2025-12-05
#   Rebalancing: M (25 times)
#   Final value: $147,091.47
#
# Running backtest for Risk Adjusted LSTM
#   Period: 2023-01-04 to 2025-12-05
#   Rebalancing: M (25 times)
#   Final value: $152,777.30

# %%
# Calculate metrics
metrics_test = compare_metrics(results_test, allocations_test)
metrics_test_formatted = format_metrics_table(metrics_test)

print("\n" + "="*80)
print("Test Set Performance Metrics")
print("="*80)
print(metrics_test_formatted.to_string())
# Out:
# ================================================================================
# Test Set Performance Metrics
# ================================================================================
#                             Total Return  Annualized Return  Annualized Volatility  Sharpe Ratio  Sortino Ratio  Max Drawdown  Calmar Ratio  Win Rate  Downside Periods  Avg Turnover
# Equal Weight                     57.8133            16.9206                 9.9712        1.4964         2.1709        9.9626        1.6984   55.5252             308.0        0.0000
# Mean-Variance (Max Sharpe)      109.8552            28.9144                12.6230        2.1322         3.1130        8.2528        3.5036   56.4802             301.0       14.1691
# Predictive Sharpe                59.1583            17.2611                10.3837        1.4697         2.0753        8.0984        2.1314   56.4802             301.0       29.5729
# 60/40 Portfolio                  47.0915            14.1357                11.0511        1.0981         1.5724       12.7185        1.1114   53.2060             325.0        0.0000
# Risk-Adjusted LSTM               52.7773            15.6286                11.0175        1.2370         1.7050       12.9442        1.2074   54.2974             317.0       17.5290

# %%
# Visualize test results
plot_equity_curves(results_test, title='Test Set: Portfolio Performance')
plt.show()

# %%
# Create comprehensive dashboard for test set
create_performance_dashboard(
    results_test,
    allocations_test,
    metrics_test
)
plt.show()

# %% [markdown]
# ## 8. Cross-Period Comparison
#
# Compare strategy performance across train/val/test periods.

# %%
# Create comparison table
comparison_data = []

for strategy_name in strategies.keys():
    comparison_data.append({
        'Strategy': strategy_name,
        'Period': 'Train',
        'Sharpe': metrics_train.loc[strategy_name, 'Sharpe Ratio'],
        'Return (%)': metrics_train.loc[strategy_name, 'Annualized Return'] * 100,
        'Volatility (%)': metrics_train.loc[strategy_name, 'Annualized Volatility'] * 100,
        'Max DD (%)': metrics_train.loc[strategy_name, 'Max Drawdown'] * 100
    })
    comparison_data.append({
        'Strategy': strategy_name,
        'Period': 'Val',
        'Sharpe': metrics_val.loc[strategy_name, 'Sharpe Ratio'],
        'Return (%)': metrics_val.loc[strategy_name, 'Annualized Return'] * 100,
        'Volatility (%)': metrics_val.loc[strategy_name, 'Annualized Volatility'] * 100,
        'Max DD (%)': metrics_val.loc[strategy_name, 'Max Drawdown'] * 100
    })
    comparison_data.append({
        'Strategy': strategy_name,
        'Period': 'Test',
        'Sharpe': metrics_test.loc[strategy_name, 'Sharpe Ratio'],
        'Return (%)': metrics_test.loc[strategy_name, 'Annualized Return'] * 100,
        'Volatility (%)': metrics_test.loc[strategy_name, 'Annualized Volatility'] * 100,
        'Max DD (%)': metrics_test.loc[strategy_name, 'Max Drawdown'] * 100
    })

comparison_df = pd.DataFrame(comparison_data)

print("\n" + "="*80)
print("Cross-Period Performance Comparison")
print("="*80)
print(comparison_df.to_string(index=False))
# Out:
# ================================================================================
# Cross-Period Performance Comparison
# ================================================================================
#                   Strategy Period  Sharpe  Return (%)  Volatility (%)  Max DD (%)
#               Equal Weight  Train  0.9989     11.0732          9.0832     16.7234
#               Equal Weight    Val -1.1463    -15.6562         15.4021     20.6666
#               Equal Weight   Test  1.4964     16.9206          9.9712      9.9626
# Mean-Variance (Max Sharpe)  Train  0.3211      5.8719         12.0565     21.4946
# Mean-Variance (Max Sharpe)    Val -1.1824    -11.2971         11.2457     19.6179
# Mean-Variance (Max Sharpe)   Test  2.1322     28.9144         12.6230      8.2528
#          Predictive Sharpe  Train  0.4068      5.9739          9.7679     16.7507
#          Predictive Sharpe    Val -1.1308    -16.4520         16.3175     21.4065
#          Predictive Sharpe   Test  1.4697     17.2611         10.3837      8.0984
#            60/40 Portfolio  Train  0.9646     11.9105         10.2741     18.5692
#            60/40 Portfolio    Val -1.1932    -18.8405         17.4662     22.8858
#            60/40 Portfolio   Test  1.0981     14.1357         11.0511     12.7185
#         Risk-Adjusted LSTM  Train  1.0213     11.8034          9.5993     17.4145
#         Risk-Adjusted LSTM    Val -1.1770    -16.0525         15.3381     21.1722
#         Risk-Adjusted LSTM   Test  1.2370     15.6286         11.0175     12.9442

# %%
# Visualize Sharpe ratio across periods
fig, ax = plt.subplots(figsize=(12, 6))

for strategy_name in strategies.keys():
    strategy_data = comparison_df[comparison_df['Strategy'] == strategy_name]
    ax.plot(strategy_data['Period'], strategy_data['Sharpe'], 
            marker='o', linewidth=2, markersize=8, label=strategy_name)

ax.set_xlabel('Period', fontsize=12)
ax.set_ylabel('Sharpe Ratio', fontsize=12)
ax.set_title('Sharpe Ratio Across Periods', fontsize=14, fontweight='bold')
ax.legend(loc='best', fontsize=10)
ax.grid(True, alpha=0.3)
ax.axhline(y=0, color='black', linestyle='--', linewidth=0.8, alpha=0.5)
plt.tight_layout()
plt.show()

# %% [markdown]
# ## 9. Key Findings and Next Steps
#
# ### Observations:
# 1. Compare baseline strategies across different market conditions
# 2. Identify which strategy performs best in terms of risk-adjusted returns
# 3. Note consistency (or lack thereof) across train/val/test periods
#
# ### Next Steps:
# 1. **Hyperparameter tuning**: Experiment with different lookback windows, rebalancing frequencies
# 2. **Additional features**: Add regime detection, macro indicators
# 3. **More baselines**: Risk parity, minimum variance, robust optimization
# 4. **RL implementation**: Build custom environment and train RL agents with Sharpe-aware reward
# 5. **Walk-forward validation**: Implement rolling window backtesting
# 6. **Transaction cost sensitivity**: Test impact of different cost assumptions

# %% [markdown]
# ## 10. Export Results
#
# Save results for future reference.

# %%
# Save metrics to CSV
metrics_train_formatted.to_csv('../data/metrics_train.csv')
metrics_val_formatted.to_csv('../data/metrics_val.csv')
metrics_test_formatted.to_csv('../data/metrics_test.csv')
comparison_df.to_csv('../data/comparison_summary.csv', index=False)

print("✓ Results saved to data/ directory")
# Out:
# ✓ Results saved to data/ directory
